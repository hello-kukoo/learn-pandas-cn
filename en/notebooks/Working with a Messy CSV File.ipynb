# %% [markdown]
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-3 col-md-3 col-lg-3">
# 	<!-- logo -->
#     <div class="img-responsive">
#       <img src="https://www.dropbox.com/s/220ncn0o5danuey/pandas-ipython-tutorials-hedaro.jpg?dl=1" title="Pandas Tutorial | Hedaro" alt="Pandas Tutorial | Hedaro">
#     </div>
# 	<!-- logo -->
#   </div>
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-6 col-md-6 col-lg-6">
# 	<!-- Pandas Tutorial -->
# 	  <center>
# 	    <br>
#         <h1>Working with a Messy CSV File</h1>
#         <p>Here is a CSV file that is an accumulation of seperate test results. The goal is to reorganize
#            the data so an actual analysis is possible.</p>
# 	  </center>
#     <!-- Pandas Tutorial -->
#   </div>
# <!-- ---------------------------------------------------- -->

# %% [markdown]
# <strong>The most popular Pandas tutorials. </strong><a href="https://gumroad.com/l/jVeRh" target="_blank"><strong>Get a total of 7 tutorials!</strong></a>

# %%
import pandas as pd
from io import StringIO
import sys

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
# Out:
# Python version 3.5.1 |Anaconda custom (64-bit)| (default, Feb 16 2016, 09:49:46) [MSC v.1900 64 bit (AMD64)]
# Pandas version 0.18.1

# %% [markdown]
# # Open the file from Hell
#
# I first just opened the file and noticed how the different chunks of data were separated. From the output below, you will see ***\n,,,,,,,,\n*** and this is what we will use as our delimiter.

# %%
with open('test.csv', 'r') as myfile:
    print(myfile.read().split(' '))
# Out:
# ['Wavelength,A1,B1,C1,D1,E1,F1,G1,H1\n300,3359,1395,2079,2890,2085,4918,1596,3069\n303,3879,1746,2391,3453,2500,5820,1961,3669\n306,4230,2010,2801,3688,2883,6554,2402,4136\n309,4452,2116,3270,3931,3137,7437,2711,4504\n312,4811,2333,3382,4025,3412,7919,2768,4764\n315,5080,2417,3658,4348,3535,8617,3023,5261\n318,5505,2725,3898,4723,3796,9350,3220,5642\n321,5895,2700,4286,5031,4075,9976,3357,5994\n324,6554,3023,4560,5656,4492,10964,3637,6437\n327,6955,3303,4929,6014,4714,11902,3821,7280\n330,7647,3541,5417,6640,5300,12998,4252,7879\n333,8349,4024,5848,7276,5751,13415,4661,8547\n336,8932,4317,6290,7784,6318,13981,4969,9279\n339,9570,4855,6944,8342,6795,14064,5444,9824\n342,10222,5143,7131,8944,7239,14165,5937,10456\n345,10730,5644,7578,9615,8021,13708,6433,10971\n348,11533,6141,8028,10175,8688,13547,7103,11357\n351,12340,6715,8320,11056,9386,13436,7653,12326\n354,13080,7360,8830,11567,10379,13658,8210,12690\n357,13612,7869,9657,12615,11159,14157,8942,13392\n360,14862,8345,10027,13564,12197,15082,9638,14346\n363,16046,9209,10718,14623,13468,16041,10420,15492\n366,17203,9854,11342,15900,14760,17230,11327,16603\n369,18746,10781,12246,17632,16112,18817,12250,18481\n372,20576,11389,13303,19385,17609,20746,13305,19869\n375,22007,11998,14021,20736,19087,22163,13930,21217\n378,23606,12461,14666,22244,20546,23834,14611,22589\n381,24806
210\n462,18652,8288,9314,19500,14650,80752,6331,16106\n465,17126,7704,8606,18255,12994,79893,5745,14793\n468,15531,7289,7906,16678,11603,78627,5222,13504\n471,13744,6677,7119,14712,9949,76655,4700,11717\n474,12027,6288,6448,13042,8566,75106,4284,10715\n477,10237,5843,5681,10887,7252,71319,3788,8883\n480,8617,5490,4983,9102,6205,69445,3545,7588\n483,6873,4929,4306,7130,5257,66962,3109,6055\n486,5688,4538,3759,5740,4633,64434,2965,5125\n489,4690,4169,3276,4750,4026,60935,2689,4278\n492,3840,3807,2868,3739,3484,58377,2418,3516\n495,3038,3310,2372,3039,3055,54266,2155,2877\n498,2496,2996,2030,2334,2612,50983,1872,2314'

# %% [markdown]
# ### Why use StringIO(x)?
#
# Since pd.read_csv() needs an actual csv file as input, we fake it using StringIO.
#
# * In cases where you want a file-like object that ***ACTS*** like a file, but is writing to an in-memory string buffer

# %%
# convert each chunk we have parsed thus far and turn it into a dataframe
pieces = [pd.read_csv(StringIO(x),sep=',') for x in data]

# get first df
pieces[0].head()
# Out:
#    Wavelength    A1    B1    C1    D1    E1    F1    G1    H1
# 0         300  3359  1395  2079  2890  2085  4918  1596  3069
# 1         303  3879  1746  2391  3453  2500  5820  1961  3669
# 2         306  4230  2010  2801  3688  2883  6554  2402  4136
# 3         309  4452  2116  3270  3931  3137  7437  2711  4504
# 4         312  4811  2333  3382  4025  3412  7919  2768  4764

# %% [markdown]
# ### Turn the list of dataframes into one big dataframe
#
# [Click Here](http://www.hedaro.com/pandas-concat) if you are unfamilar with the ***Concat*** function.

# %%
merged = pd.concat(pieces)
merged.head()
# Out:
#        A1  A10  A2  A3  A4  A5  A6  A7  A8  A9     ...      H10  H2  H3  H4  \
# 0  3359.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN     ...      NaN NaN NaN NaN
# 1  3879.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN     ...      NaN NaN NaN NaN
# 2  4230.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN     ...      NaN NaN NaN NaN
# 3  4452.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN     ...      NaN NaN NaN NaN
# 4  4811.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN     ...      NaN NaN NaN NaN
#
#    H5  H6  H7  H8  H9  Wavelength
# 0 NaN NaN NaN NaN NaN         300
# 1 NaN NaN NaN NaN NaN         303
# 2 NaN NaN NaN NaN NaN         306
# 3 NaN NaN NaN NaN NaN         309
# 4 NaN NaN NaN NaN NaN         312
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Some Pandas magic to shape the data just how we want it

# %%
df = pd.DataFrame(merged.set_index('Wavelength').unstack()).reset_index()

# we rename the columns as Pandas gives them generic names
df.columns = ['index', 'Wavelength', 'values']


df.head()
# Out:
#   index  Wavelength values
# 0    A1         300   3359
# 1    A1         303   3879
# 2    A1         306   4230
# 3    A1         309   4452
# 4    A1         312   4811

# %% [markdown]
# # Now on to the index CSV file

# %% [markdown]
# ### As you can see, we basically used the same stradegy here

# %%
with open ('index.csv', 'r') as myfile:
    data = myfile.read().split('\n,,,,,,,,,\n')

data
# Out:
# ['index,,,,,,,,,\nA1,A2,A3,A4,A5,A6,A7,A8,A9,A10\nB1,B2,B3,B4,B5,B6,B7,B8,B9,B10\nC1,C2,C3,C4,C5,C6,C7,C8,C9,C10\nD1,D2,D3,D4,D5,D6,D7,D8,D9,D10\nE1,E2,E3,E4,E5,E6,E7,E8,E9,E10\nF1,F2,F3,F4,F5,F6,F7,F8,F9,F10\nG1,G2,G3,G4,G5,G6,G7,G8,G9,G10\nH1,H2,H3,H4,H5,H6,H7,H8,H9,H10',
#  'strain,,,,,,,,,\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl\nwt,mut,clin,ep,bl,wt,mut,clin,ep,bl',
#  'col,,,,,,,,,\nblue,blue,blue,blue,blue,blue,blue,blue,blue,blue\nred,red,red,red,red,red,red,red,red,red\ngreen,green,green,green,green,green,green,green,green,green\nblack,black,black,black,black,black,black,black,black,black\norange,orange,orange,orange,orange,orange,orange,orange,orange,orange\nyellow,yellow,yellow,yellow,yellow,yellow,yellow,yellow,yellow,yellow\npink,pink,pink,pink,pink,pink,pink,pink,pink,pink\npurple,purple,purple,purple,purple,purple,purple,purple,purple,purple']

# %%
pieces = [pd.read_csv(StringIO(x),sep=',') for x in data]

# We do get a bunch on Unnamed columns
pieces[1]
# Out:
#   strain Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     wt        mut       clin         ep         bl         wt        mut
# 1     wt        mut       clin         ep         bl         wt        mut
# 2     wt        mut       clin         ep         bl         wt        mut
# 3     wt        mut       clin         ep         bl         wt        mut
# 4     wt        mut       clin         ep         bl         wt        mut
# 5     wt        mut       clin         ep         bl         wt        mut
# 6     wt        mut       clin         ep         bl         wt        mut
# 7     wt        mut       clin         ep         bl         wt        mut
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       clin         ep         bl
# 1       clin         ep         bl
# 2       clin         ep         bl
# 3       clin         ep         bl
# 4       clin         ep         bl
# 5       clin         ep         bl
# 6       clin         ep         bl
# 7       clin         ep         bl

# %%
# we then glue all the pieces and make one big dataframe
merged2 = pd.concat(pieces, axis=1)
merged2
# Out:
#   index Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0    A1         A2         A3         A4         A5         A6         A7
# 1    B1         B2         B3         B4         B5         B6         B7
# 2    C1         C2         C3         C4         C5         C6         C7
# 3    D1         D2         D3         D4         D5         D6         D7
# 4    E1         E2         E3         E4         E5         E6         E7
# 5    F1         F2         F3         F4         F5         F6         F7
# 6    G1         G2         G3         G4         G5         G6         G7
# 7    H1         H2         H3         H4         H5         H6         H7
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9    ...         col Unnamed: 1 Unnamed: 2  \
# 0         A8         A9        A10    ...        blue       blue       blue
# 1         B8         B9        B10    ...         red        red        red
# 2         C8         C9        C10    ...       green      green      green
# 3         D8         D9        D10    ...       black      black      black
# 4         E8         E9        E10    ...      orange     orange     orange
# 5         F8         F9        F10    ...      yellow     yellow     yellow
# 6         G8         G9        G10    ...        pink       pink       pink
# 7         H8         H9        H10    ...      purple     purple     purple
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       blue       blue       blue       blue       blue       blue       blue
# 1        red        red        red        red        red        red        red
# 2      green      green      green      green      green      green      green
# 3      black      black      black      black      black      black      black
# 4     orange     orange     orange     orange     orange     orange     orange
# 5     yellow     yellow     yellow     yellow     yellow     yellow     yellow
# 6       pink       pink       pink       pink       pink       pink       pink
# 7     purple     purple     purple     purple     purple     purple     purple
#
# [8 rows x 30 columns]

# %% [markdown]
# ### We rename the columns here because in the next sections, we are going to take advantage of the different groups having identical column names

# %%
merged2 = merged2.rename(columns = {'strain':'index', 'col':'index'})

# Each of the three groups will have identical column names
merged2
# Out:
#   index Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0    A1         A2         A3         A4         A5         A6         A7
# 1    B1         B2         B3         B4         B5         B6         B7
# 2    C1         C2         C3         C4         C5         C6         C7
# 3    D1         D2         D3         D4         D5         D6         D7
# 4    E1         E2         E3         E4         E5         E6         E7
# 5    F1         F2         F3         F4         F5         F6         F7
# 6    G1         G2         G3         G4         G5         G6         G7
# 7    H1         H2         H3         H4         H5         H6         H7
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9    ...       index Unnamed: 1 Unnamed: 2  \
# 0         A8         A9        A10    ...        blue       blue       blue
# 1         B8         B9        B10    ...         red        red        red
# 2         C8         C9        C10    ...       green      green      green
# 3         D8         D9        D10    ...       black      black      black
# 4         E8         E9        E10    ...      orange     orange     orange
# 5         F8         F9        F10    ...      yellow     yellow     yellow
# 6         G8         G9        G10    ...        pink       pink       pink
# 7         H8         H9        H10    ...      purple     purple     purple
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       blue       blue       blue       blue       blue       blue       blue
# 1        red        red        red        red        red        red        red
# 2      green      green      green      green      green      green      green
# 3      black      black      black      black      black      black      black
# 4     orange     orange     orange     orange     orange     orange     orange
# 5     yellow     yellow     yellow     yellow     yellow     yellow     yellow
# 6       pink       pink       pink       pink       pink       pink       pink
# 7     purple     purple     purple     purple     purple     purple     purple
#
# [8 rows x 30 columns]

# %% [markdown]
# ### Here is the way I figured out how to reshape the data. You might find there is a beter/easier way.

# %%
# get a list of all the column names
col = merged2.columns.unique()

pieces = []

# pick a column name and stick it in a list
# note every iteration will have a df of three columns
for c in col:
    n = merged2[c]
    
    # We make every chunk has the same column names
    # We do this so that when we "concat", we end up with three columns
    n.columns = ['index','strain','col']
    pieces.append(n)
    
pieces[0]
# Out:
#   index strain     col
# 0    A1     wt    blue
# 1    B1     wt     red
# 2    C1     wt   green
# 3    D1     wt   black
# 4    E1     wt  orange
# 5    F1     wt  yellow
# 6    G1     wt    pink
# 7    H1     wt  purple

# %%
# combine all of the pieces into one big dataframe
lookup = pd.concat(pieces) 
lookup.head(20)
# Out:
#   index strain     col
# 0    A1     wt    blue
# 1    B1     wt     red
# 2    C1     wt   green
# 3    D1     wt   black
# 4    E1     wt  orange
# 5    F1     wt  yellow
# 6    G1     wt    pink
# 7    H1     wt  purple
# 0    A2    mut    blue
# 1    B2    mut     red
# 2    C2    mut   green
# 3    D2    mut   black
# 4    E2    mut  orange
# 5    F2    mut  yellow
# 6    G2    mut    pink
# 7    H2    mut  purple
# 0    A3   clin    blue
# 1    B3   clin     red
# 2    C3   clin   green
# 3    D3   clin   black

# %%
# We can then join on the "index" columns on both dataframes
df.merge(lookup, how='left', left_on='index', right_on='index')
# Out:
#       index  Wavelength values strain     col
# 0        A1         300   3359     wt    blue
# 1        A1         303   3879     wt    blue
# 2        A1         306   4230     wt    blue
# 3        A1         309   4452     wt    blue
# 4        A1         312   4811     wt    blue
# 5        A1         315   5080     wt    blue
# 6        A1         318   5505     wt    blue
# 7        A1         321   5895     wt    blue
# 8        A1         324   6554     wt    blue
# 9        A1         327   6955     wt    blue
# 10       A1         330   7647     wt    blue
# 11       A1         333   8349     wt    blue
# 12       A1         336   8932     wt    blue
# 13       A1         339   9570     wt    blue
# 14       A1         342  10222     wt    blue
# 15       A1         345  10730     wt    blue
# 16       A1         348  11533     wt    blue
# 17       A1         351  12340     wt    blue
# 18       A1         354  13080     wt    blue
# 19       A1         357  13612     wt    blue
# 20       A1         360  14862     wt    blue
# 21       A1         363  16046     wt    blue
# 22       A1         366  17203     wt    blue
# 23       A1         369  18746     wt    blue
# 24       A1         372  20576     wt    blue
# 25       A1         375  22007     wt    blue
# 26       A1         378  23606     wt    blue
# 27       A1         381  24806     wt    blue
# 28       A1         384  26349     wt    blue
# 29       A1         387  27383     wt    blue
# ...     ...         ...    ...    ...     ...
# 53570    H9         411    NaN     ep  purple
# 53571    H9         414    NaN     ep  purple
# 53572    H9         417    NaN     ep  purple
# 53573    H9         420    NaN     ep  purple
# 53574    H9         423    NaN     ep  purple
# 53575    H9         426    NaN     ep  purple
# 53576    H9         429    NaN     ep  purple
# 53577    H9         432    NaN     ep  purple
# 53578    H9         435    NaN     ep  purple
# 53579    H9         438    NaN     ep  purple
# 53580    H9         441    NaN     ep  purple
# 53581    H9         444    NaN     ep  purple
# 53582    H9         447    NaN     ep  purple
# 53583    H9         450    NaN     ep  purple
# 53584    H9         453    NaN     ep  purple
# 53585    H9         456    NaN     ep  purple
# 53586    H9         459    NaN     ep  purple
# 53587    H9         462    NaN     ep  purple
# 53588    H9         465    NaN     ep  purple
# 53589    H9         468    NaN     ep  purple
# 53590    H9         471    NaN     ep  purple
# 53591    H9         474    NaN     ep  purple
# 53592    H9         477    NaN     ep  purple
# 53593    H9         480    NaN     ep  purple
# 53594    H9         483    NaN     ep  purple
# 53595    H9         486    NaN     ep  purple
# 53596    H9         489    NaN     ep  purple
# 53597    H9         492    NaN     ep  purple
# 53598    H9         495    NaN     ep  purple
# 53599    H9         498    NaN     ep  purple
#
# [53600 rows x 5 columns]

# %% [markdown]
# ### All of this could have been avoided if each chunk/piece of data was saved into a separate csv file.

# %% [markdown]
# <p class="text-muted">This tutorial was created by <a href="http://www.hedaro.com" target="_blank"><strong>HEDARO</strong></a></p>
